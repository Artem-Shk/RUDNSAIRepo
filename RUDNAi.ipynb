# %% [markdown]
# <a href="https://colab.research.google.com/github/Artem-Shk/RUDNSAIRepo/blob/main/RUDNAi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q diffusers transformers accelerate

# %%
import cv2
import os

def extract_frames(video_path, output_path, frame_size):
    # Создаем папку для сохранения кадров, если она не существует
    if not os.path.exists(output_path):
        os.makedirs(output_path)

    # Открываем видеофайл
    video = cv2.VideoCapture(video_path)
    success, image = video.read()
    count = 0
    video_length = int(video.get(cv2.CAP_PROP_FRAME_COUNT))  # Получаем общую продолжительность видео
    step = int(video_length / 10)  # Вычисляем шаг для сохранения каждого 10% кадра

    while success:
        # Изменяем размер кадра
        resized_image = cv2.resize(image, frame_size)

        # Сохраняем кадр в файл, если count кратен шагу
        if count % step == 0:
            cv2.imwrite(f"{output_path}/frame{count}.jpg", resized_image)
        success, image = video.read()
        count += 1

    video.release()

# Пример использования функции
video_path = "/content/drive/MyDrive/Videos/0.mp4"  # Путь к видеофайлу (загрузите видео в Google Colab)
output_path = "/content/frames/0"  # Путь для сохранения кадров
frame_size = (1280, 720)  # Размер кадров (ширина, высота)

extract_frames(video_path, output_path, frame_size)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
import torch
import glob
import numpy as np
from diffusers import StableDiffusionPipeline, DPMSolverMultistepScheduler
from matplotlib import pyplot as plt
from PIL import Image, ImageDraw, ImageFont
from google.colab import drive
drive.mount('/content/drive')


class Model:
  def __init__(self):
    self.model_id = "stabilityai/stable-diffusion-2-1"
    self.model = self.build_model()
  def build_model(self):
    pipe = StableDiffusionPipeline.from_pretrained(self.model_id, torch_dtype=torch.float16)
    pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
    model = pipe.to('cuda')
    return pipe
  def res():
    return Model.build_model(self)

folder_path = '/content/frames/0'

# Получение списка путей к изображениям в папке
image_paths = glob.glob(folder_path + '*.jpg')

# Загрузка изображений
images = []
for path in image_paths:
    image = Image.open(path)
    images.append(np.array(image))

# Создание пайплайна Stable Diffusion
pipeline = Model().build_model()

# Применение Stable Diffusion к каждому изображению
diffused_images = []
for image in images:
    diffused_image = pipeline.apply(image)
    diffused_images.append(diffused_image)

# Объединение всех diffused_images в одну картинку
result_image = np.mean(diffused_images, axis=0)

# Сохранение результирующей картинки
result_image = Image.fromarray(result_image.astype(np.uint8))
result_image.save('/content/result_image.jpg')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-d2932019c0e2> in <cell line: 48>()
#      46
#      47 # Сохранение результирующей картинки
# ---> 48 result_image = Image.fromarray(result_image.astype(np.uint8))
#      49 result_image.save('/content/result_image.jpg')
#
# ...

# %%
# !pip install diffusers
from PIL import Image
import numpy as np
from diffusers import StableDiffusionPipeline
import glob
import torch

model_id = "stabilityai/stable-diffusion-2-1"
def build_model():
    pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
    pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
    model = pipe.to('cuda')
    return pipe

model = build_model()

# Путь к папке с изображениями
# Out:
# ...
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-ebae19e31878> in <cell line: 15>()
#      13     return pipe
#      14
# ---> 15 model = build_model()
#      16
#      17 # Путь к папке с изображениями
#
# <ipython-input-17-ebae19e31878> in build_model()
#      10     pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
#      11     pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
# ---> 12     model = pipe.to('cuda')
#      13     return pipe
#      14
#
# /usr/local/lib/python3.10/dist-packages/diffusers/pipelines/pipeline_utils.py in to(self, torch_device, torch_dtype, silence_dtype_warnings)
#     731                 )
#     732             else:
# --> 733                 module.to(torch_device, torch_dtype)
#     734
# ...

# %%
# !pip install diffusers

from PIL import Image
import numpy as np
from diffusers import StableDiffusionPipeline

# Загрузка изображений
image_paths = ['image1.jpg', 'image2.jpg', 'image3.jpg']
images = []
for path in image_paths:
    image = Image.open(path)
    images.append(np.array(image))

# Создание пайплайна Stable Diffusion
pipeline = StableDiffusionPipeline()

# Применение Stable Diffusion к каждому изображению
diffused_images = []
for image in images:
    diffused_image = pipeline.apply(image)
    diffused_images.append(diffused_image)

# Объединение всех diffused_images в одну картинку
result_image = np.mean(diffused_images, axis=0)

# Сохранение результирующей картинки
result_image = Image.fromarray(result_image.astype(np.uint8))
result_image.save('/content/result_image.jpg')
# Out:
# ...
# ^C
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-afef67568133> in <cell line: 10>()
#       9 images = []
#      10 for path in image_paths:
# ---> 11     image = Image.open(path)
#      12     images.append(np.array(image))
#      13
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3225
#    3226     if filename:
# -> 3227         fp = builtins.open(filename, "rb")
#    3228         exclusive_fp = True
#    3229
#
# FileNotFoundError: [Errno 2] No such file or directory: 'image1.jpg'
